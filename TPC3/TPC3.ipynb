# %%
import random
def menu():
    print("""Bem vindo! Este programa ordena listas. Como queres criar a tua lista?
    (1) - Introduzir a lista à mão
    (2) - Gerar lista c/valores aleatórios
    ...
    (0) - Sair
     """)

def criarListaM():
    N=int(input("Quantos números queres introduzir? "))
    LM=[]
    for i in range(N):
        a=int(input('Introduza o ' + str(i+1) + ' elemento:'))
        LM.append(a)
        print(" ")
    print (LM)
    return LM
    
def criarListaA():
    N=int(input("Quantos números queres na tua lista? "))
    print(" ")
    LA=[]
    for i in range(N):
        LA.append(random.randint(0,100))
    print (LA)
    return LA

def sort(L):
    trocas=0
    for i in range(len(L)):
        if i<(len(L)-1):
            if L[i+1]<L[i]:
                tempM=L[i]
                tempm=L[i+1]
                L[i]=tempm
                L[i+1]=tempM  
                trocas=trocas+1
    
    if trocas>=1:
        (sort(L))    
    
    return L


a = "1"
while a!=0:
    menu()
    a=int(input("Opçao: "))
    if a==1:
        print(sort(criarListaM()))
        print(" ")
    elif a==2: 
        print(sort(criarListaA()))
        print(" ")
    elif a==0:
        print("Até à proxima!")
    else:
        print("Opção inválida!")
